# %% [markdown]
# # CNN Visualization
#
# 해당 문서는 CNN사용시 Input Tile로 사용되는 부분을 시각적으로 보여주기 위해서 만들어진 코드입니다.

# %%
# %pylab inline
import cv
import cv2
import numpy as np
from PIL import Image
from IPython.core.display import display
import scipy.misc
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Constants

# %%
SAMPLE_IMAGE = '../../data/images/rainbow_six.jpg'

# %% [markdown]
# ### Implementation

# %%
def slice_image(img, width, height, x_size=10, y_size=10):
    # Get image meta data
    img_width, img_height = img.size
    img_format = img.format.lower()
    
    width_interval = (img_width - width) //x_size
    height_interval = (img_height - height) //y_size
    
    print img_width, img_height
    print width_interval, height_interval
    for i in range(y_size):
        row_images = []
        for j in range(x_size):
            x_p = j * width_interval
            y_p = i * height_interval
            cropped = img.crop((x_p, y_p, x_p + width, y_p +height))
#             cropped = cv2.cvtColor(np.array(cropped), cv2.COLOR_RGB2BGR)
            display(cropped)
            
            
#             display(cropped)
            
#     x = cv.fromarray(np.concatenate(row_images, axis=1))

img = Image.open(SAMPLE_IMAGE)
slice_image(img, 100, 100)
# Out:
# 800 450
# 70 35
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951555D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951556D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951555D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951556D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951555D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951556D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951555D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951556D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951555D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951556D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951555D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951556D0>
# <PIL.Image._ImageCrop image mode=RGB size=100x100 at 0x7F1A951555D0>
# ...

# %%
img = cv2.imread

# %%
img = Image.open(SAMPLE_IMAGE)
slice_image(img, 100, 100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-d314321b3469> in <module>()
# ----> 1 img = Image.open(SAMPLE_IMAGE)
#       2 slice_image(img, 100, 100)
#
# AttributeError: type object 'Image' has no attribute 'open'

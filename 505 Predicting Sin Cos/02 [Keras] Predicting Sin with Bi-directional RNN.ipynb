# %%
# %pylab inline
import numpy as np

from keras.models import Sequential
from keras.layers import SimpleRNN, Bidirectional, Dense
from keras.metrics import mean_squared_error
from keras.wrappers.scikit_learn import KerasClassifier

from sklearn.metrics import make_scorer, r2_score
from sklearn.model_selection import GridSearchCV

from IPython.display import SVG, Image
from keras.utils.vis_utils import model_to_dot
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using TensorFlow backend.

# %% [markdown]
# # DATA

# %%
SIZE = 200

data = np.arange(-27, 27, 0.1)
data = np.sin(data)

def make_x_y(data, size=500):
    N = data.shape[0]
    
    data_x = np.zeros((N-size*2, size))
    data_y = np.zeros((N-size*2, size))
    for i, idx in enumerate(range(0, N-size*2)):
        x = data[idx: idx+size]
        y = data[idx+size: idx+size*2]
        
        data_x[idx, :x.shape[0]] = x
        data_y[idx, :y.shape[0]] = y
        
    data_x = np.asarray(data_x)
    data_y = np.asarray(data_y)
    
    data_x = data_x.reshape(-1, size, 1)
    data_y = data_y.reshape(-1, size, 1)
    
    # Shuffle
    permu = np.random.permutation(data_x.shape[0])
    data_x = data_x[permu]
    data_y = data_y[permu]
    return data_x, data_y


x, y = make_x_y(data, size=SIZE)
print('x:', x.shape)
print('y:', y.shape)

plot(data)
# Out:
# x: (140, 200, 1)
# y: (140, 200, 1)

# %% [markdown]
# ## Visualize Data

# %%
def visualize(data_x, data_y):
    fig, sub_plots = subplots(2, 2)
    for columns in sub_plots:
        for sp in columns:
            sp.get_xaxis().set_visible(False)
            sp.get_yaxis().set_visible(False)
            
            
            r = np.random.randint(data_x.shape[0])
            sample_x = data_x[r]
            sample_y = data_y[r]
            
            
            sample_x = sample_x.reshape(sample_x.shape[0])
            sample_y = sample_y.reshape(sample_y.shape[0])
            tick_x = range(0, SIZE)
            tick_y = range(SIZE, SIZE*2)
            
            sp.plot(tick_x, sample_x)
            sp.plot(tick_y, sample_y)

visualize(x, y)

# %% [markdown]
# # Bi-directional RNN

# %%
def create_model(lstm_out=10, optimizer='adam'):
    model = Sequential(name='lstm')
    model.add(Bidirectional(SimpleRNN(units=16, return_sequences=True), 
                            batch_input_shape=(None, None, 1)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[mean_squared_error])
    return model

model = create_model()
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# # Train

# %%
model.fit(x, y, verbose=2, nb_epoch=100)
# Out:
# /usr/local/lib/python3.6/site-packages/keras/models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
#  - 1s - loss: 0.5349 - mean_squared_error: 0.5349
# Epoch 2/100
#  - 1s - loss: 0.3643 - mean_squared_error: 0.3643
# Epoch 3/100
#  - 1s - loss: 0.2595 - mean_squared_error: 0.2595
# Epoch 4/100
#  - 1s - loss: 0.1953 - mean_squared_error: 0.1953
# Epoch 5/100
#  - 1s - loss: 0.1415 - mean_squared_error: 0.1415
# Epoch 6/100
#  - 1s - loss: 0.0913 - mean_squared_error: 0.0913
# Epoch 7/100
#  - 1s - loss: 0.0508 - mean_squared_error: 0.0508
# Epoch 8/100
#  - 1s - loss: 0.0254 - mean_squared_error: 0.0254
# Epoch 9/100
#  - 1s - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 10/100
#  - 1s - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 11/100
#  - 1s - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 12/100
#  - 1s - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 13/100
#  - 1s - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 14/100
#  - 1s - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 15/100
#  - 1s - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 16/100
#  - 1s - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 17/100
#  - 1s - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 18/100
#  - 1s - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 19/100
#  - 1s - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 20/100
#  - 1s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 21/100
#  - 0s - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 22/100
#  - 1s - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 23/100
#  - 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 24/100
#  - 0s - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 25/100
#  - 0s - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 26/100
#  - 0s - loss: 0.0111 - mean_squared_error: 0.0111
# Epoch 27/100
#  - 0s - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 28/100
#  - 0s - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 29/100
#  - 0s - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 30/100
#  - 0s - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 31/100
#  - 0s - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 32/100
#  - 0s - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 33/100
#  - 0s - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 34/100
#  - 0s - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 35/100
#  - 0s - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 36/100
#  - 0s - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 37/100
#  - 0s - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 38/100
#  - 0s - loss: 0.0102 - mean_squared_error: 0.0102
# Epoch 39/100
#  - 0s - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 40/100
#  - 1s - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 41/100
#  - 0s - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 42/100
#  - 0s - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 43/100
#  - 0s - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 44/100
#  - 0s - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 45/100
#  - 0s - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 46/100
#  - 0s - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 47/100
#  - 0s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 48/100
#  - 0s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 49/100
#  - 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 50/100
#  - 0s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 51/100
#  - 0s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 52/100
#  - 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 53/100
#  - 0s - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 54/100
#  - 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 55/100
#  - 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 56/100
#  - 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 57/100
#  - 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 58/100
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 59/100
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 60/100
#  - 0s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 61/100
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 62/100
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 63/100
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 64/100
#  - 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 65/100
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 66/100
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 67/100
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 68/100
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 69/100
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 70/100
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 71/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 72/100
#  - 0s - loss: 0.0093 - mean_squared_error: 0.0093
# Epoch 73/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 74/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 75/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 76/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 77/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 78/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 79/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 80/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 81/100
#  - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 82/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 83/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 84/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 85/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 86/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 87/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 88/100
#  - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 89/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 90/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 91/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 92/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 93/100
#  - 1s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 94/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 95/100
#  - 1s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 96/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 97/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 98/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 99/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 100/100
#  - 0s - loss: 0.0090 - mean_squared_error: 0.0090

# %%
def accuracy(y_true, y_pred):
    y_true = y_true.reshape((-1, SIZE))
    y_pred = y_pred.reshape((-1, SIZE))
    score = r2_score(y_true, y_pred, multioutput='variance_weighted')
    error = ((y_true - y_pred)**2).mean()
    print(f'mse: {error:.2}')
    print(f'r^2: {score:.2}')
    return score

def visualize_prediction(data_x, data_y):
    data_p = model.predict(data_x)
    data_x = data_x.reshape((-1, SIZE))
    data_y = data_y.reshape((-1, SIZE))
    data_p = data_p.reshape((-1, SIZE))
    accuracy(data_y, data_p)
        
    fig, sub_plots = subplots(2, 2)
    for col_plots in sub_plots:
        for sp in col_plots:
            sp.get_xaxis().set_visible(False)
            sp.get_yaxis().set_visible(False)
        
            idx = np.random.randint(data_x.shape[0])
            
            sp.plot(data_y[idx], color='#333333')
            sp.plot(data_p[idx], color='red')


visualize_prediction(x, y)
# Out:
# mse: 0.009
# r^2: 0.98

# %%
# %pylab inline

import numpy as np
import pandas as pd

from lifelines.plotting import plot_lifetimes
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Data

# %%
pd.re('User Access Data for Survival Analysis.edf')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-3-de7e44948b2b> in <module>
# ----> 1 pd.read_excel('User Access Data for Survival Analysis.edf')
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

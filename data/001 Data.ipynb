# %% [markdown]
# # Vision
#
# #### [CIFAR-10, CIFAR-100](https://www.cs.toronto.edu/~kriz/cifar.html)
#
#
#
# #### [ImageNet](http://image-net.org/)
#
#
#
# #### [LSUN](http://lsun.cs.princeton.edu/2016/)
#
#
#
# #### [PASCAL VOC](http://host.robots.ox.ac.uk/pascal/VOC/)
#
#
# #### [The Street View House Numbers (SVHN) Dataset](http://ufldl.stanford.edu/housenumbers/)
#
# #### [MS COCO](http://mscoco.org/)
#
# Image Captioning
#
# #### [Visual Genome](http://visualgenome.org/)
#
#
#
# #### [Labeled Faces in the Wild Home](http://vis-www.cs.umass.edu/lfw/)

# %% [markdown]
# # Natural Language
#
# ####  [Text Classification Datasets](https://drive.google.com/drive/u/0/folders/0Bz8a_Dbh9Qhbfll6bVpmNUtUcFdjYmF2SEpmZUZUcVNiMUw1TWN6RDV3a0JHT3kxLVhVR2M)
#
# 구글 드라이브에 있음
#
# #### [The WikiText Long Term Dependency Language Modeling Dataset](http://metamind.io/research/the-wikitext-long-term-dependency-language-modeling-dataset/)
#
#
#
# #### [Question Pairs](https://data.quora.com/First-Quora-Dataset-Release-Question-Pairs)
#
#
#
# #### [Stanford Question Answering Dataset (SQuAD)](https://rajpurkar.github.io/SQuAD-explorer/)
#
#
# #### [Question-Answer Dataset](http://www.cs.cmu.edu/~ark/QA-data/)
#
#
#
# #### [Maluuba Datasets](https://datasets.maluuba.com/)
#
#
#
# #### [1 Billion Word Language Model Benchmark](http://www.statmt.org/lm-benchmark/)
#
# #### [Common Crawl](http://commoncrawl.org/the-data/)
#
# #### [bAbI](https://research.fb.com/projects/babi/)
#
# #### [Stanford Sentiment Treebank](http://nlp.stanford.edu/sentiment/code.html)
#
# #### [20 Newsgroups](http://qwone.com/~jason/20Newsgroups/)
#
# #### [Reuters](https://archive.ics.uci.edu/ml/datasets/Reuters-21578+Text+Categorization+Collection)
#
# This is a collection of documents that appeared on Reuters newswire in 1987. The documents were assembled and indexed with categories<br>
#
#
#
# #### [IMDB - Large Movie Review Dataset](http://ai.stanford.edu/~amaas/data/sentiment/)
# This is a dataset for binary sentiment classification containing substantially more data than previous benchmark datasets. We provide a set of 25,000 highly polar movie reviews for training, and 25,000 for testing. There is additional unlabeled data for use as well. Raw text and already processed bag of words formats are provided. See the README file contained in the release for more details.<br>
#
#
# #### [UCI - Spambase Data Set ](https://archive.ics.uci.edu/ml/datasets/Spambase)

# %% [markdown]
# # Speech
#
# #### [2000 HUB5 English Evaluation Transcripts](https://catalog.ldc.upenn.edu/LDC2002T43)
#
#
#
#
# #### [LibriSpeech ASR corpus](http://www.openslr.org/12/)
# The data is derived from read audiobooks from the LibriVox project, and has been carefully segmented and aligned
#
# #### [VoxForge](http://www.voxforge.org/)
#
# #### [TIMIT](https://catalog.ldc.upenn.edu/LDC93S1)
#
# #### [CHiME](http://spandh.dcs.shef.ac.uk/chime_challenge/data.html)
#
# speech data that is recorded in real noisy environments (on a bus, cafe, pedestrian area, and street junction) uttered by actual talkers
#
#
# #### [TED-LIUM Corpus](http://www-lium.univ-lemans.fr/en/content/ted-lium-corpus)
# The TED-LIUM corpus was made from audio talks and their transcriptions available on the TED website

# %% [markdown]
# # Recommendation and ranking systems
#
# #### [Netflix Challenge](http://www.netflixprize.com/)
#
# #### [MovieLens](https://grouplens.org/datasets/movielens/)
# GroupLens Research has collected and made available rating data sets from the MovieLens web site <br>
#
#
# #### [Million Song Dataset Challenge](https://www.kaggle.com/c/msdchallenge#description)
#
# The Million Song Dataset Challenge aims at being the best possible offline evaluation of a music recommendation system
#
#
# #### [Last.FM](http://grouplens.org/datasets/hetrec-2011/)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
years = range(1950, 2011, 10)
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plot(years, gdp, color='red', marker='o', linestyle='solid')

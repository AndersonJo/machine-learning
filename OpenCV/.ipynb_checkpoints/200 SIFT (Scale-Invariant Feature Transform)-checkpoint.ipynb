# %%
# %pylab inline
import cv2
import numpy as np
from lshash import LSHash
print 'OpenCV Version: ' + cv2.__version__
# Out:
# Populating the interactive namespace from numpy and matplotlib
# OpenCV Version: 3.1.0-dev

# %%
img1 = cv2.imread('../data/images/rainbowsix.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

print 'image1 shape:\t', img1.shape
print 'gray1 shape:\t', gray1.shape
imshow(gray1, cmap='Greys_r')
# Out:
# image1 shape:	(450, 800, 3)
# gray1 shape:	(450, 800)

# %%
img2 = cv2.imread('../data/images/rainbosix_cropped.jpg')
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
print 'image2 shape:\t', img2.shape
print 'gray2 shape:\t', gray2.shape
imshow(gray2, cmap='Greys_r')
# Out:
# image2 shape:	(319, 379, 3)
# gray2 shape:	(319, 379)

# %%
sift = cv2.xfeatures2d.SIFT_create()
kps1, des1 = sift.detectAndCompute(img1, None) 
kp_img = cv2.drawKeypoints(gray1, kps, img1) 
imshow(img1, cmap='Greys_r')

# %%
kps2, des2 = sift.detectAndCompute(img2, None, descriptors=(0, 0, 5)) 
kp_img = cv2.drawKeypoints(gray2, kps, img2) 
imshow(img2, cmap='Greys_r')

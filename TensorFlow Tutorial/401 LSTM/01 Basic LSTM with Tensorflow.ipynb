# %% [markdown]
# # LSTM with Tensorflow
#
# * [RECURRENT NEURAL NETWORK REGULARIZATION](https://arxiv.org/pdf/1409.2329.pdf) - TensorFlow BasicLSTMCell에 사용된 논문
# * [Simple Implementation of LSTM in Tensorflow in 50 lines](https://gist.github.com/nivwusquorum/b18ce332bde37e156034e5d3f60f8a23)
# * [LSTM Cell to learn zero](https://gist.github.com/nivwusquorum/160d5cf7e1e82c21fad3ebf04f039317)
#
#
#
#
#
# * [Understanding LSTM Networks](http://colah.github.io/posts/2015-08-Understanding-LSTMs/)
# * [2003 Tutorial on LSTM Recurrent Nets](http://people.idsia.ch/~juergen/lstm2003tutorial.pdf)
# * [LSTM Recurrent Networks Learn Simple Context Free and Context Sensitive Languages](ftp://ftp.idsia.ch/pub/juergen/L-IEEE.pdf)
# * [LSTM: A Search Space Odyssey](https://arxiv.org/pdf/1503.04069.pdf)

# %%
# %pylab inline
import numpy as np
import tensorflow as tf
import pandas as pd

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.contrib.rnn import RNNCell, BasicLSTMCell, MultiRNNCell, DropoutWrapper
from tensorflow.examples.tutorials.mnist import input_data
from datetime import datetime
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Data

# %%
# Load Data
data = pd.read_csv('../../data/time-series/international-airline-passengers.csv', 
                   names=['passenger'],
                   skiprows=1, usecols=[1])

# Normalize Data using Min-Max Scaler 
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
data = data.astype('float32')

# Seperate Train and Test Data
_size = int(len(data) * 0.7) # 144
train, test = data[:_size], data[_size:] # 100, 44

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        dataX.append(dataset[i])
        dataY.append(dataset[i+1])
    return np.array(dataX), np.array(dataY)

def reshape(dataset):
    return np.reshape(dataset, (dataset.shape[0], 1, dataset.shape[1]))

look_back = 1
train_x, train_y = create_dataset(train, look_back)
test_x, test_y = create_dataset(test, look_back)

train_x = reshape(train_x)
train_y = reshape(train_y)
test_x = reshape(test_x)
test_y = reshape(test_y) 

print('Train X:', train_x.shape)
print('Train Y:', train_y.shape)
print('Test X:', test_x.shape)
print('Test Y:', test_y.shape)

title('International Airline Passengers per year')
ylabel('the number of airline passengers')
xlabel('years')
grid()
plot(data)
# Out:
# Train X: (98, 1, 1)
# Train Y: (98, 1, 1)
# Test X: (42, 1, 1)
# Test Y: (42, 1, 1)

# %% [markdown]
# ### Model

# %%
hidden_size = 4

with tf.variable_scope('test' + str(np.random.randint(0, 100000))):
    inputs = tf.placeholder('float32', shape=[None, None, 1], name='inputs') # [batch, time, in]
    targets = tf.placeholder('float32', shape=[None, None, 1], name='targets') # [batch, time, out]
    
    cell = BasicLSTMCell(hidden_size, forget_bias=1.0, state_is_tuple=True)
    cell = DropoutWrapper(cell)
    state = cell.zero_state(1, 'float32')

    rnn_outputs, rnn_states = tf.nn.dynamic_rnn(cell, inputs, initial_state=state, time_major=True)
    rnn_outputs = tf.reshape(rnn_outputs, [-1, hidden_size])
    
    w = tf.get_variable('weights', [hidden_size, 1], initializer=tf.random_normal_initializer())
    b = tf.get_variable('biases', [1, 1], initializer=tf.constant_initializer())
    
    dense1 = tf.matmul(rnn_outputs, w) + b
    dense2 = tf.reduce_sum(dense1, reduction_indices=[1])
    prediction = tf.nn.sigmoid(dense2)
    
    error2 = tf.square(targets - prediction)
    error3 = tf.reduce_mean(error2, reduction_indices=[1, 2])
    train_fn = tf.train.AdamOptimizer(learning_rate=0.001).minimize(error3)

# %% [markdown]
# ### Initialize Tensorflow Session and Variables

# %%
init_op = tf.global_variables_initializer()

gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.001, allow_growth=True)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
sess.run(init_op)

# %% [markdown]
# ### Train

# %%
def train(x, y, test_x, test_y, epoch=100, train_less=0.0019, test_less=0.03):
    now = datetime.now()
    N = len(x)
    g_costs = []
    g_test_costs = []
    for global_step in range(epoch):
        costs = []
        
        # Shuffle
        permu = np.random.permutation(x.shape[0])
        x = x[permu]
        y = y[permu]
        
        for _ in range(N*5):
            i = np.random.randint(0, N)
            sample_x = x[i: i+1]
            sample_y = y[i: i+1]

            cost, _ = sess.run([error3, train_fn], feed_dict={inputs: sample_x, targets: sample_y})
            costs.append(np.sum(cost))
        
        # Evaluate Training cost
        _c = np.sum(costs)/len(costs)
        g_costs.append(_c)
        
        # Evaluate Test Cost
        test_predicted = sess.run(error3, feed_dict={inputs: test_x, targets: test_y})
        test_cost = np.sum(test_predicted)/len(test_predicted)
        g_test_costs.append(test_cost)
        
        print('[%d]Training Cost: %.6f \tTest Cost:%.6f' % (global_step + 1, _c, test_cost))
        if test_less > test_cost and train_less > _c:
            break
    
    
    seconds = (datetime.now() - now).total_seconds()
    return seconds, g_costs, g_test_costs

seconds, costs, test_costs = train(train_x, train_y, test_x, test_y)
print('걸린시각:%s 초'% seconds)
plot(costs, label='costs')
plot(test_costs, label='test costs')
grid()
legend()
# Out:
# [1]Training Cost: 0.002039 	Test Cost:0.045539
# [2]Training Cost: 0.002029 	Test Cost:0.044540
# [3]Training Cost: 0.002406 	Test Cost:0.048315
# [4]Training Cost: 0.001997 	Test Cost:0.048850
# [5]Training Cost: 0.002043 	Test Cost:0.042293
# [6]Training Cost: 0.001982 	Test Cost:0.043987
# [7]Training Cost: 0.002055 	Test Cost:0.045066
# [8]Training Cost: 0.002327 	Test Cost:0.044057
# [9]Training Cost: 0.002162 	Test Cost:0.044024
# [10]Training Cost: 0.002048 	Test Cost:0.045628
# [11]Training Cost: 0.002268 	Test Cost:0.042307
# [12]Training Cost: 0.002020 	Test Cost:0.042359
# [13]Training Cost: 0.002011 	Test Cost:0.042843
# [14]Training Cost: 0.002351 	Test Cost:0.039733
# [15]Training Cost: 0.002226 	Test Cost:0.041188
# [16]Training Cost: 0.002082 	Test Cost:0.040787
# [17]Training Cost: 0.002217 	Test Cost:0.043264
# [18]Training Cost: 0.002196 	Test Cost:0.039084
# [19]Training Cost: 0.001842 	Test Cost:0.038991
# [20]Training Cost: 0.001979 	Test Cost:0.040600
# [21]Training Cost: 0.002089 	Test Cost:0.037074
# [22]Training Cost: 0.001979 	Test Cost:0.037811
# [23]Training Cost: 0.002001 	Test Cost:0.037584
# [24]Training Cost: 0.002112 	Test Cost:0.037501
# [25]Training Cost: 0.001989 	Test Cost:0.036955
# [26]Training Cost: 0.002004 	Test Cost:0.036910
# [27]Training Cost: 0.002187 	Test Cost:0.037596
# [28]Training Cost: 0.002065 	Test Cost:0.035820
# [29]Training Cost: 0.002094 	Test Cost:0.036391
# [30]Training Cost: 0.001957 	Test Cost:0.035734
# [31]Training Cost: 0.001881 	Test Cost:0.035702
# [32]Training Cost: 0.002250 	Test Cost:0.036076
# [33]Training Cost: 0.002041 	Test Cost:0.036106
# [34]Training Cost: 0.002250 	Test Cost:0.035773
# [35]Training Cost: 0.002156 	Test Cost:0.035059
# [36]Training Cost: 0.002027 	Test Cost:0.035989
# [37]Training Cost: 0.002071 	Test Cost:0.035296
# [38]Training Cost: 0.001960 	Test Cost:0.034517
# [39]Training Cost: 0.001896 	Test Cost:0.034371
# [40]Training Cost: 0.002021 	Test Cost:0.034067
# [41]Training Cost: 0.002042 	Test Cost:0.033666
# [42]Training Cost: 0.001733 	Test Cost:0.033574
# [43]Training Cost: 0.002009 	Test Cost:0.033229
# [44]Training Cost: 0.002294 	Test Cost:0.033936
# [45]Training Cost: 0.002267 	Test Cost:0.034619
# [46]Training Cost: 0.001855 	Test Cost:0.033110
# [47]Training Cost: 0.001935 	Test Cost:0.034218
# [48]Training Cost: 0.002094 	Test Cost:0.034856
# [49]Training Cost: 0.002098 	Test Cost:0.034499
# [50]Training Cost: 0.001840 	Test Cost:0.033655
# [51]Training Cost: 0.002103 	Test Cost:0.034220
# [52]Training Cost: 0.002003 	Test Cost:0.033612
# [53]Training Cost: 0.002170 	Test Cost:0.033746
# [54]Training Cost: 0.001938 	Test Cost:0.033941
# [55]Training Cost: 0.002127 	Test Cost:0.032763
# [56]Training Cost: 0.002192 	Test Cost:0.033874
# [57]Training Cost: 0.001916 	Test Cost:0.033045
# [58]Training Cost: 0.002128 	Test Cost:0.033749
# [59]Training Cost: 0.002157 	Test Cost:0.034020
# [60]Training Cost: 0.001928 	Test Cost:0.034257
# [61]Training Cost: 0.002174 	Test Cost:0.033594
# [62]Training Cost: 0.002194 	Test Cost:0.033886
# [63]Training Cost: 0.001823 	Test Cost:0.032682
# [64]Training Cost: 0.002173 	Test Cost:0.033941
# [65]Training Cost: 0.002100 	Test Cost:0.034304
# [66]Training Cost: 0.002077 	Test Cost:0.034035
# [67]Training Cost: 0.002045 	Test Cost:0.035317
# [68]Training Cost: 0.002000 	Test Cost:0.035536
# [69]Training Cost: 0.001861 	Test Cost:0.035324
# [70]Training Cost: 0.002107 	Test Cost:0.038239
# [71]Training Cost: 0.002031 	Test Cost:0.035440
# [72]Training Cost: 0.002097 	Test Cost:0.035876
# [73]Training Cost: 0.001995 	Test Cost:0.035114
# [74]Training Cost: 0.002170 	Test Cost:0.037023
# [75]Training Cost: 0.002362 	Test Cost:0.037299
# [76]Training Cost: 0.002076 	Test Cost:0.036852
# [77]Training Cost: 0.002222 	Test Cost:0.038158
# [78]Training Cost: 0.002035 	Test Cost:0.038946
# [79]Training Cost: 0.001943 	Test Cost:0.038037
# [80]Training Cost: 0.002114 	Test Cost:0.038510
# [81]Training Cost: 0.001986 	Test Cost:0.037283
# [82]Training Cost: 0.001941 	Test Cost:0.037889
# [83]Training Cost: 0.002022 	Test Cost:0.036804
# [84]Training Cost: 0.002215 	Test Cost:0.038527
# [85]Training Cost: 0.002045 	Test Cost:0.039273
# [86]Training Cost: 0.002172 	Test Cost:0.038337
# [87]Training Cost: 0.002132 	Test Cost:0.040190
# [88]Training Cost: 0.002030 	Test Cost:0.041720
# [89]Training Cost: 0.002154 	Test Cost:0.039116
# [90]Training Cost: 0.001918 	Test Cost:0.041298
# [91]Training Cost: 0.001863 	Test Cost:0.042419
# [92]Training Cost: 0.001990 	Test Cost:0.040667
# [93]Training Cost: 0.002090 	Test Cost:0.042235
# [94]Training Cost: 0.002149 	Test Cost:0.042174
# [95]Training Cost: 0.001847 	Test Cost:0.041066
# [96]Training Cost: 0.002221 	Test Cost:0.041648
# [97]Training Cost: 0.002094 	Test Cost:0.040670
# [98]Training Cost: 0.002162 	Test Cost:0.043348
# [99]Training Cost: 0.002221 	Test Cost:0.040293
# [100]Training Cost: 0.001903 	Test Cost:0.040532
# 걸린시각:84.90433 초

# %%
train_predicted = sess.run(prediction, feed_dict={inputs: train_x})
test_predicted = sess.run(prediction, feed_dict={inputs: test_x})

train_predicted = scaler.inverse_transform(train_predicted.reshape(train_predicted.shape[0]))
test_predicted =  scaler.inverse_transform(test_predicted.reshape(test_predicted.shape[0]))

plot_train_x = np.arange(0, train_predicted.shape[0])
plot_test_x = np.arange(plot_train_x.shape[0] + 2, plot_train_x.shape[0] + test_predicted.shape[0] + 2)

plot(scaler.inverse_transform(data), color='#333333', label='original data')
plot(plot_train_x, train_predicted, plot_test_x, test_predicted, color='red', label='predict')

legend(loc='upper left')
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:374: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

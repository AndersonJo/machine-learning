# %% [markdown]
# # TF-IDF
#
# ## TF
#
# $$ TF(t, d) = \frac{\text{t의 갯수 in d}}{\text{단어의 갯수 in d}} $$
#
#  - TF는 기본적으로 문서 하나에서의 특정 단어 갯수를 의미 한다.
#  - **stopwords 가 높은 값으로 나옴**
#  - t : term (word)
#  - d : document (문서 하나를 의미)
#  - corpus: set of documents (전체 문서들을 의미)
#
# TF만으로 단어의 중요성을 수치로 나타내면 좋겠지만, 문제는 is, are, the 같은 stopwords 가 높은 값을 가지게 됩니다. <br>
# 보완할 필요가 있습니다.
#
#
# ## DF
#
# $$ DF = \text{t를 포함하고 있는 document의 갯수} $$
#
# 예를 들어, "사과"라는 단어가 document 1 에서 50번 나오고, document 2에서 100번, 그리고 document 3에서 0번 나온다면.. <br>
# DF의 값은 2 입니다. 왜냐하면 "사과"를 포함하고 있는 **문서의 갯수**는 2개 이기 때문입니다.
#
# ## IDF
#
# $$ \begin{align}
# \text{IDF (vanila)} &= \log\left( \frac{N}{df} \right) \\
# \text{IDF (smooth)} &= \log\left( \frac{N}{df} \right) +1 \\
# \text{IDF (another smooth)} &= \log\left( \frac{N}{df + 1} \right) +1 \\
# \end{align} $$
#
#  - 주 목적은 TF에서 높에 나온 stopwords들을 값을 낮추도록 weight를 줌
#  - **stopwods에 대한 값은 매우 낮게 나옴**
#  - log 를 사용하는 이유는 N값이 높아질수록 값이 커지는 문제를 해결하기 위해서
#
#
# ## TF-IDF
#
# $$ \text{TF-IDF}(t, d) = TF \times IDF $$
#
# 최종적으로 TF 그리고 IDF 를 서로 곱해주면 TF-IDF 값이 나옵니다.
#
# \* SKLearn에서 구현한 것을 똑같이 해보려고 하였으나, 공식이 좀 다른듯 함. <br>

# %% [markdown]
# # SKLearn

# %%
corpus = [
    'This is the first document. is this first one? this is the first one',
    'This document is the second document. the document!',
    'this is document. is this the second document?',
    'Is this the robot document?',
    'this is the document. this is the first one document.',
    'this this this the the the first is is is document document',
]

# %%
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
cm = sns.light_palette('red', as_cmap=True)

vectorizer = TfidfVectorizer()
tfidf_mtx = vectorizer.fit_transform(corpus).toarray()

tfidf_df = pd.DataFrame(tfidf_mtx.round(2),
                        columns=vectorizer.get_feature_names())
tfidf_df.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_39435_row0_col0,#T_39435_row0_col4,#T_39435_row0_col5,#T_39435_row1_col1,#T_39435_row1_col2,#T_39435_row1_col3,#T_39435_row1_col4,#T_39435_row1_col7,#T_39435_row2_col1,#T_39435_row2_col3,#T_39435_row2_col4,#T_39435_row2_col6,#T_39435_row3_col1,#T_39435_row3_col3,#T_39435_row3_col5,#T_39435_row4_col4,#T_39435_row4_col5,#T_39435_row5_col3,#T_39435_row5_col4,#T_39435_row5_col5{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_39435_row0_col1,#T_39435_row0_col3,#T_39435_row1_col0,#T_39435_row2_col5,#T_39435_row3_col4,#T_39435_row5_col2,#T_39435_row5_col6,#T_39435_row5_col7{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_39435_row0_col2,#T_39435_row0_col7{
#             background-color:  #fa6b6b;
#             color:  #000000;
#         }#T_39435_row0_col6{
#             background-color:  #f3e8e7;
#             color:  #000000;
#         }#T_39435_row1_col5{
#             background-color:  #fe0f0f;
#             color:  #f1f1f1;
#         }#T_39435_row1_col6{
#             background-color:  #fd2c2c;
#             color:  #f1f1f1;
#         }#T_39435_row2_col0{
#             background-color:  #fb5858;
#             color:  #000000;
#         }#T_39435_row2_col2,#T_39435_row2_col7{
#             background-color:  #fe1818;
#             color:  #f1f1f1;
#         }#T_39435_row3_col0{
#             background-color:  #f79c9c;
#             color:  #000000;
#         }#T_39435_row3_col2,#T_39435_row3_col7{
#             background-color:  #f79d9d;
#             color:  #000000;
#         }#T_39435_row3_col6{
#             background-color:  #f6a9a9;
#             color:  #000000;
#         }#T_39435_row4_col0{
#             background-color:  #f97272;
#             color:  #000000;
#         }#T_39435_row4_col1{
#             background-color:  #f96e6e;
#             color:  #000000;
#         }#T_39435_row4_col2,#T_39435_row4_col7{
#             background-color:  #fb4a4a;
#             color:  #000000;
#         }#T_39435_row4_col3{
#             background-color:  #fd2828;
#             color:  #f1f1f1;
#         }#T_39435_row4_col6{
#             background-color:  #fb5050;
#             color:  #000000;
#         }#T_39435_row5_col0{
#             background-color:  #f89494;
#             color:  #000000;
#         }#T_39435_row5_col1{
#             background-color:  #f88686;
#             color:  #000000;
#         }</style><table id="T_39435_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >document</th>        <th class="col_heading level0 col1" >first</th>        <th class="col_heading level0 col2" >is</th>        <th class="col_heading level0 col3" >one</th>        <th class="col_heading level0 col4" >robot</th>        <th class="col_heading level0 col5" >second</th>        <th class="col_heading level0 col6" >the</th>        <th class="col_heading level0 col7" >this</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_39435_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_39435_row0_col0" class="data row0 col0" >0.130000</td>
#                         <td id="T_39435_row0_col1" class="data row0 col1" >0.610000</td>
#                         <td id="T_39435_row0_col2" class="data row0 col2" >0.390000</td>
#                         <td id="T_39435_row0_col3" class="data row0 col3" >0.480000</td>
#                         <td id="T_39435_row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_39435_row0_col5" class="data row0 col5" >0.000000</td>
#                         <td id="T_39435_row0_col6" class="data row0 col6" >0.260000</td>
#                         <td id="T_39435_row0_col7" class="data row0 col7" >0.390000</td>
#             </tr>
#             <tr>
#                         <th id="T_39435_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_39435_row1_col0" class="data row1 col0" >0.700000</td>
#                         <td id="T_39435_row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_39435_row1_col2" class="data row1 col2" >0.230000</td>
#                         <td id="T_39435_row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_39435_row1_col4" class="data row1 col4" >0.000000</td>
#                         <td id="T_39435_row1_col5" class="data row1 col5" >0.430000</td>
#                         <td id="T_39435_row1_col6" class="data row1 col6" >0.470000</td>
#                         <td id="T_39435_row1_col7" class="data row1 col7" >0.230000</td>
#             </tr>
#             <tr>
#                         <th id="T_39435_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_39435_row2_col0" class="data row2 col0" >0.490000</td>
#                         <td id="T_39435_row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_39435_row2_col2" class="data row2 col2" >0.490000</td>
#                         <td id="T_39435_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_39435_row2_col4" class="data row2 col4" >0.000000</td>
#                         <td id="T_39435_row2_col5" class="data row2 col5" >0.460000</td>
#                         <td id="T_39435_row2_col6" class="data row2 col6" >0.250000</td>
#                         <td id="T_39435_row2_col7" class="data row2 col7" >0.490000</td>
#             </tr>
#             <tr>
#                         <th id="T_39435_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_39435_row3_col0" class="data row3 col0" >0.330000</td>
#                         <td id="T_39435_row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_39435_row3_col2" class="data row3 col2" >0.330000</td>
#                         <td id="T_39435_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_39435_row3_col4" class="data row3 col4" >0.750000</td>
#                         <td id="T_39435_row3_col5" class="data row3 col5" >0.000000</td>
#                         <td id="T_39435_row3_col6" class="data row3 col6" >0.330000</td>
#                         <td id="T_39435_row3_col7" class="data row3 col7" >0.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_39435_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_39435_row4_col0" class="data row4 col0" >0.430000</td>
#                         <td id="T_39435_row4_col1" class="data row4 col1" >0.330000</td>
#                         <td id="T_39435_row4_col2" class="data row4 col2" >0.430000</td>
#                         <td id="T_39435_row4_col3" class="data row4 col3" >0.400000</td>
#                         <td id="T_39435_row4_col4" class="data row4 col4" >0.000000</td>
#                         <td id="T_39435_row4_col5" class="data row4 col5" >0.000000</td>
#                         <td id="T_39435_row4_col6" class="data row4 col6" >0.430000</td>
#                         <td id="T_39435_row4_col7" class="data row4 col7" >0.430000</td>
#             </tr>
#             <tr>
#                         <th id="T_39435_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_39435_row5_col0" class="data row5 col0" >0.350000</td>
#                         <td id="T_39435_row5_col1" class="data row5 col1" >0.270000</td>
#                         <td id="T_39435_row5_col2" class="data row5 col2" >0.520000</td>
#                         <td id="T_39435_row5_col3" class="data row5 col3" >0.000000</td>
#                         <td id="T_39435_row5_col4" class="data row5 col4" >0.000000</td>
#                         <td id="T_39435_row5_col5" class="data row5 col5" >0.000000</td>
#                         <td id="T_39435_row5_col6" class="data row5 col6" >0.520000</td>
#                         <td id="T_39435_row5_col7" class="data row5 col7" >0.520000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Numpy
#
# ## Counter

# %%
from sklearn.feature_extraction.text import CountVectorizer

cvec = CountVectorizer()
cnt_mtx = cvec.fit_transform(corpus).toarray()


columns = cvec.get_feature_names()
counter_df = pd.DataFrame(cnt_mtx,
                          columns=columns)

counter_df.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_a63b5_row0_col0,#T_a63b5_row0_col4,#T_a63b5_row0_col5,#T_a63b5_row1_col1,#T_a63b5_row1_col2,#T_a63b5_row1_col3,#T_a63b5_row1_col4,#T_a63b5_row1_col7,#T_a63b5_row2_col1,#T_a63b5_row2_col3,#T_a63b5_row2_col4,#T_a63b5_row2_col6,#T_a63b5_row3_col0,#T_a63b5_row3_col1,#T_a63b5_row3_col2,#T_a63b5_row3_col3,#T_a63b5_row3_col5,#T_a63b5_row3_col6,#T_a63b5_row3_col7,#T_a63b5_row4_col4,#T_a63b5_row4_col5,#T_a63b5_row5_col3,#T_a63b5_row5_col4,#T_a63b5_row5_col5{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_a63b5_row0_col1,#T_a63b5_row0_col2,#T_a63b5_row0_col3,#T_a63b5_row0_col7,#T_a63b5_row1_col0,#T_a63b5_row1_col5,#T_a63b5_row2_col5,#T_a63b5_row3_col4,#T_a63b5_row5_col2,#T_a63b5_row5_col6,#T_a63b5_row5_col7{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_a63b5_row0_col6,#T_a63b5_row1_col6,#T_a63b5_row2_col0,#T_a63b5_row2_col2,#T_a63b5_row2_col7,#T_a63b5_row4_col0,#T_a63b5_row4_col2,#T_a63b5_row4_col3,#T_a63b5_row4_col6,#T_a63b5_row4_col7,#T_a63b5_row5_col0{
#             background-color:  #f97878;
#             color:  #000000;
#         }#T_a63b5_row4_col1,#T_a63b5_row5_col1{
#             background-color:  #f7a0a0;
#             color:  #000000;
#         }</style><table id="T_a63b5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >document</th>        <th class="col_heading level0 col1" >first</th>        <th class="col_heading level0 col2" >is</th>        <th class="col_heading level0 col3" >one</th>        <th class="col_heading level0 col4" >robot</th>        <th class="col_heading level0 col5" >second</th>        <th class="col_heading level0 col6" >the</th>        <th class="col_heading level0 col7" >this</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a63b5_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a63b5_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_a63b5_row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_a63b5_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_a63b5_row0_col3" class="data row0 col3" >2</td>
#                         <td id="T_a63b5_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_a63b5_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_a63b5_row0_col6" class="data row0 col6" >2</td>
#                         <td id="T_a63b5_row0_col7" class="data row0 col7" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_a63b5_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a63b5_row1_col0" class="data row1 col0" >3</td>
#                         <td id="T_a63b5_row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_a63b5_row1_col2" class="data row1 col2" >1</td>
#                         <td id="T_a63b5_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_a63b5_row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_a63b5_row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_a63b5_row1_col6" class="data row1 col6" >2</td>
#                         <td id="T_a63b5_row1_col7" class="data row1 col7" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_a63b5_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_a63b5_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_a63b5_row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_a63b5_row2_col2" class="data row2 col2" >2</td>
#                         <td id="T_a63b5_row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_a63b5_row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_a63b5_row2_col5" class="data row2 col5" >1</td>
#                         <td id="T_a63b5_row2_col6" class="data row2 col6" >1</td>
#                         <td id="T_a63b5_row2_col7" class="data row2 col7" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_a63b5_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_a63b5_row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_a63b5_row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_a63b5_row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_a63b5_row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_a63b5_row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_a63b5_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_a63b5_row3_col6" class="data row3 col6" >1</td>
#                         <td id="T_a63b5_row3_col7" class="data row3 col7" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_a63b5_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_a63b5_row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_a63b5_row4_col1" class="data row4 col1" >1</td>
#                         <td id="T_a63b5_row4_col2" class="data row4 col2" >2</td>
#                         <td id="T_a63b5_row4_col3" class="data row4 col3" >1</td>
#                         <td id="T_a63b5_row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_a63b5_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_a63b5_row4_col6" class="data row4 col6" >2</td>
#                         <td id="T_a63b5_row4_col7" class="data row4 col7" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_a63b5_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_a63b5_row5_col0" class="data row5 col0" >2</td>
#                         <td id="T_a63b5_row5_col1" class="data row5 col1" >1</td>
#                         <td id="T_a63b5_row5_col2" class="data row5 col2" >3</td>
#                         <td id="T_a63b5_row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_a63b5_row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_a63b5_row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_a63b5_row5_col6" class="data row5 col6" >3</td>
#                         <td id="T_a63b5_row5_col7" class="data row5 col7" >3</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## TF
#
# 빈번하게 나오는 단어들은 값이 높게 나옵니다. <br>
# 실제로 is, this, document 같이 많이 나온 단어일수록, TF의 평균값은 높게 나옵니다.

# %%
# TF
tf = (cnt_mtx/cnt_mtx.sum(axis=1)[:, None])

# Visualization
_df = pd.DataFrame(tf.round(2), columns=columns) 

display(_df.style.background_gradient(cmap=cm))
_df = pd.DataFrame({'sum': counter_df.sum(),
                    'mean': _df.mean(), 
                    'max': _df.max(), 
                    'min': _df.min()})

_df.sort_values('sum', ascending=False)
# Out:
# <style  type="text/css" >
# #T_898a1_row0_col0,#T_898a1_row0_col4,#T_898a1_row0_col5,#T_898a1_row1_col1,#T_898a1_row1_col2,#T_898a1_row1_col3,#T_898a1_row1_col4,#T_898a1_row1_col7,#T_898a1_row2_col1,#T_898a1_row2_col3,#T_898a1_row2_col4,#T_898a1_row2_col6,#T_898a1_row3_col1,#T_898a1_row3_col3,#T_898a1_row3_col5,#T_898a1_row4_col4,#T_898a1_row4_col5,#T_898a1_row5_col3,#T_898a1_row5_col4,#T_898a1_row5_col5{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_898a1_row0_col1,#T_898a1_row0_col3,#T_898a1_row1_col0,#T_898a1_row1_col5,#T_898a1_row1_col6,#T_898a1_row2_col2,#T_898a1_row2_col5,#T_898a1_row2_col7,#T_898a1_row3_col4,#T_898a1_row5_col2,#T_898a1_row5_col6,#T_898a1_row5_col7{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_898a1_row0_col2,#T_898a1_row0_col7{
#             background-color:  #fb4949;
#             color:  #000000;
#         }#T_898a1_row0_col6{
#             background-color:  #f5cbcb;
#             color:  #000000;
#         }#T_898a1_row2_col0{
#             background-color:  #fa6565;
#             color:  #000000;
#         }#T_898a1_row3_col0,#T_898a1_row4_col0{
#             background-color:  #f88b8b;
#             color:  #000000;
#         }#T_898a1_row3_col2,#T_898a1_row3_col6,#T_898a1_row3_col7,#T_898a1_row4_col2,#T_898a1_row4_col6,#T_898a1_row4_col7{
#             background-color:  #fa5c5c;
#             color:  #000000;
#         }#T_898a1_row4_col1{
#             background-color:  #f97e7e;
#             color:  #000000;
#         }#T_898a1_row4_col3{
#             background-color:  #fc4545;
#             color:  #000000;
#         }#T_898a1_row5_col0{
#             background-color:  #f7a3a3;
#             color:  #000000;
#         }#T_898a1_row5_col1{
#             background-color:  #f79595;
#             color:  #000000;
#         }</style><table id="T_898a1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >document</th>        <th class="col_heading level0 col1" >first</th>        <th class="col_heading level0 col2" >is</th>        <th class="col_heading level0 col3" >one</th>        <th class="col_heading level0 col4" >robot</th>        <th class="col_heading level0 col5" >second</th>        <th class="col_heading level0 col6" >the</th>        <th class="col_heading level0 col7" >this</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_898a1_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_898a1_row0_col0" class="data row0 col0" >0.070000</td>
#                         <td id="T_898a1_row0_col1" class="data row0 col1" >0.210000</td>
#                         <td id="T_898a1_row0_col2" class="data row0 col2" >0.210000</td>
#                         <td id="T_898a1_row0_col3" class="data row0 col3" >0.140000</td>
#                         <td id="T_898a1_row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_898a1_row0_col5" class="data row0 col5" >0.000000</td>
#                         <td id="T_898a1_row0_col6" class="data row0 col6" >0.140000</td>
#                         <td id="T_898a1_row0_col7" class="data row0 col7" >0.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_898a1_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_898a1_row1_col0" class="data row1 col0" >0.380000</td>
#                         <td id="T_898a1_row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_898a1_row1_col2" class="data row1 col2" >0.120000</td>
#                         <td id="T_898a1_row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_898a1_row1_col4" class="data row1 col4" >0.000000</td>
#                         <td id="T_898a1_row1_col5" class="data row1 col5" >0.120000</td>
#                         <td id="T_898a1_row1_col6" class="data row1 col6" >0.250000</td>
#                         <td id="T_898a1_row1_col7" class="data row1 col7" >0.120000</td>
#             </tr>
#             <tr>
#                         <th id="T_898a1_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_898a1_row2_col0" class="data row2 col0" >0.250000</td>
#                         <td id="T_898a1_row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_898a1_row2_col2" class="data row2 col2" >0.250000</td>
#                         <td id="T_898a1_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_898a1_row2_col4" class="data row2 col4" >0.000000</td>
#                         <td id="T_898a1_row2_col5" class="data row2 col5" >0.120000</td>
#                         <td id="T_898a1_row2_col6" class="data row2 col6" >0.120000</td>
#                         <td id="T_898a1_row2_col7" class="data row2 col7" >0.250000</td>
#             </tr>
#             <tr>
#                         <th id="T_898a1_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_898a1_row3_col0" class="data row3 col0" >0.200000</td>
#                         <td id="T_898a1_row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_898a1_row3_col2" class="data row3 col2" >0.200000</td>
#                         <td id="T_898a1_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_898a1_row3_col4" class="data row3 col4" >0.200000</td>
#                         <td id="T_898a1_row3_col5" class="data row3 col5" >0.000000</td>
#                         <td id="T_898a1_row3_col6" class="data row3 col6" >0.200000</td>
#                         <td id="T_898a1_row3_col7" class="data row3 col7" >0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_898a1_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_898a1_row4_col0" class="data row4 col0" >0.200000</td>
#                         <td id="T_898a1_row4_col1" class="data row4 col1" >0.100000</td>
#                         <td id="T_898a1_row4_col2" class="data row4 col2" >0.200000</td>
#                         <td id="T_898a1_row4_col3" class="data row4 col3" >0.100000</td>
#                         <td id="T_898a1_row4_col4" class="data row4 col4" >0.000000</td>
#                         <td id="T_898a1_row4_col5" class="data row4 col5" >0.000000</td>
#                         <td id="T_898a1_row4_col6" class="data row4 col6" >0.200000</td>
#                         <td id="T_898a1_row4_col7" class="data row4 col7" >0.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_898a1_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_898a1_row5_col0" class="data row5 col0" >0.170000</td>
#                         <td id="T_898a1_row5_col1" class="data row5 col1" >0.080000</td>
#                         <td id="T_898a1_row5_col2" class="data row5 col2" >0.250000</td>
#                         <td id="T_898a1_row5_col3" class="data row5 col3" >0.000000</td>
#                         <td id="T_898a1_row5_col4" class="data row5 col4" >0.000000</td>
#                         <td id="T_898a1_row5_col5" class="data row5 col5" >0.000000</td>
#                         <td id="T_898a1_row5_col6" class="data row5 col6" >0.250000</td>
#                         <td id="T_898a1_row5_col7" class="data row5 col7" >0.250000</td>
#             </tr>
#     </tbody></table>
#           sum      mean   max   min
# is         12  0.205000  0.25  0.12
# this       12  0.205000  0.25  0.12
# document   11  0.211667  0.38  0.07
# the        11  0.193333  0.25  0.12
# first       5  0.065000  0.21  0.00
# one         3  0.040000  0.14  0.00
# second      2  0.040000  0.12  0.00
# robot       1  0.033333  0.20  0.00

# %% [markdown]
# ## DF
#
# 해당 단어를 포함하고 있는 document의 갯수 입니다.

# %%
# DF
df = cnt_mtx.astype(bool).sum(axis=0).astype(float)
display(pd.DataFrame([df], columns=columns))
# Out:
#    document  first   is  one  robot  second  the  this
# 0       6.0    3.0  6.0  2.0    1.0     2.0  6.0   6.0

# %% [markdown]
# ## IDF
#
# IDF에서는 TF와는 반대로 stopwords (is, this, document, the) 같은 단어들의 IDF값이 더 작습니다.<br>
# 즉 rare 한 단어들일수록 IDF값은 높아집니다.

# %%
# IDF
n_d, _ = cnt_mtx.shape
idf = np.log(n_d/df + 1) + 1

display(pd.DataFrame([idf], columns=columns))

# Visualization
_df = pd.DataFrame({'sum': counter_df.sum(),
                    'idf': idf})
_df.sort_values('sum', ascending=False)
# Out:
#    document     first        is       one    robot    second       the  \
# 0  1.693147  2.098612  1.693147  2.386294  2.94591  2.386294  1.693147
#
#        this
# 0  1.693147
#           sum       idf
# is         12  1.693147
# this       12  1.693147
# document   11  1.693147
# the        11  1.693147
# first       5  2.098612
# one         3  2.386294
# second      2  2.386294
# robot       1  2.945910

# %% [markdown]
# # TF-IDF
#
# 최종적으로 tf * idf 를 합니다.

# %%
tfidf_ = (tf * idf)

_df = pd.DataFrame(tfidf_.round(2), columns=columns)
_df.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
# #T_b0dc6_row0_col0,#T_b0dc6_row0_col4,#T_b0dc6_row0_col5,#T_b0dc6_row1_col1,#T_b0dc6_row1_col2,#T_b0dc6_row1_col3,#T_b0dc6_row1_col4,#T_b0dc6_row1_col7,#T_b0dc6_row2_col1,#T_b0dc6_row2_col3,#T_b0dc6_row2_col4,#T_b0dc6_row2_col6,#T_b0dc6_row3_col1,#T_b0dc6_row3_col3,#T_b0dc6_row3_col5,#T_b0dc6_row4_col4,#T_b0dc6_row4_col5,#T_b0dc6_row5_col3,#T_b0dc6_row5_col4,#T_b0dc6_row5_col5{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_b0dc6_row0_col1,#T_b0dc6_row0_col3,#T_b0dc6_row1_col0,#T_b0dc6_row1_col5,#T_b0dc6_row1_col6,#T_b0dc6_row2_col2,#T_b0dc6_row2_col5,#T_b0dc6_row2_col7,#T_b0dc6_row3_col4,#T_b0dc6_row5_col2,#T_b0dc6_row5_col6,#T_b0dc6_row5_col7{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_b0dc6_row0_col2,#T_b0dc6_row0_col7{
#             background-color:  #fc4545;
#             color:  #000000;
#         }#T_b0dc6_row0_col6{
#             background-color:  #f5cece;
#             color:  #000000;
#         }#T_b0dc6_row2_col0{
#             background-color:  #fa6363;
#             color:  #000000;
#         }#T_b0dc6_row3_col0,#T_b0dc6_row4_col0{
#             background-color:  #f88888;
#             color:  #000000;
#         }#T_b0dc6_row3_col2,#T_b0dc6_row3_col6,#T_b0dc6_row3_col7,#T_b0dc6_row4_col2,#T_b0dc6_row4_col6,#T_b0dc6_row4_col7{
#             background-color:  #fa5b5b;
#             color:  #000000;
#         }#T_b0dc6_row4_col1{
#             background-color:  #f98080;
#             color:  #000000;
#         }#T_b0dc6_row4_col3{
#             background-color:  #fb4747;
#             color:  #000000;
#         }#T_b0dc6_row5_col0{
#             background-color:  #f7a5a5;
#             color:  #000000;
#         }#T_b0dc6_row5_col1{
#             background-color:  #f79696;
#             color:  #000000;
#         }</style><table id="T_b0dc6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >document</th>        <th class="col_heading level0 col1" >first</th>        <th class="col_heading level0 col2" >is</th>        <th class="col_heading level0 col3" >one</th>        <th class="col_heading level0 col4" >robot</th>        <th class="col_heading level0 col5" >second</th>        <th class="col_heading level0 col6" >the</th>        <th class="col_heading level0 col7" >this</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b0dc6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b0dc6_row0_col0" class="data row0 col0" >0.120000</td>
#                         <td id="T_b0dc6_row0_col1" class="data row0 col1" >0.450000</td>
#                         <td id="T_b0dc6_row0_col2" class="data row0 col2" >0.360000</td>
#                         <td id="T_b0dc6_row0_col3" class="data row0 col3" >0.340000</td>
#                         <td id="T_b0dc6_row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_b0dc6_row0_col5" class="data row0 col5" >0.000000</td>
#                         <td id="T_b0dc6_row0_col6" class="data row0 col6" >0.240000</td>
#                         <td id="T_b0dc6_row0_col7" class="data row0 col7" >0.360000</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b0dc6_row1_col0" class="data row1 col0" >0.630000</td>
#                         <td id="T_b0dc6_row1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_b0dc6_row1_col2" class="data row1 col2" >0.210000</td>
#                         <td id="T_b0dc6_row1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_b0dc6_row1_col4" class="data row1 col4" >0.000000</td>
#                         <td id="T_b0dc6_row1_col5" class="data row1 col5" >0.300000</td>
#                         <td id="T_b0dc6_row1_col6" class="data row1 col6" >0.420000</td>
#                         <td id="T_b0dc6_row1_col7" class="data row1 col7" >0.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b0dc6_row2_col0" class="data row2 col0" >0.420000</td>
#                         <td id="T_b0dc6_row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_b0dc6_row2_col2" class="data row2 col2" >0.420000</td>
#                         <td id="T_b0dc6_row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_b0dc6_row2_col4" class="data row2 col4" >0.000000</td>
#                         <td id="T_b0dc6_row2_col5" class="data row2 col5" >0.300000</td>
#                         <td id="T_b0dc6_row2_col6" class="data row2 col6" >0.210000</td>
#                         <td id="T_b0dc6_row2_col7" class="data row2 col7" >0.420000</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc6_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b0dc6_row3_col0" class="data row3 col0" >0.340000</td>
#                         <td id="T_b0dc6_row3_col1" class="data row3 col1" >0.000000</td>
#                         <td id="T_b0dc6_row3_col2" class="data row3 col2" >0.340000</td>
#                         <td id="T_b0dc6_row3_col3" class="data row3 col3" >0.000000</td>
#                         <td id="T_b0dc6_row3_col4" class="data row3 col4" >0.590000</td>
#                         <td id="T_b0dc6_row3_col5" class="data row3 col5" >0.000000</td>
#                         <td id="T_b0dc6_row3_col6" class="data row3 col6" >0.340000</td>
#                         <td id="T_b0dc6_row3_col7" class="data row3 col7" >0.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc6_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b0dc6_row4_col0" class="data row4 col0" >0.340000</td>
#                         <td id="T_b0dc6_row4_col1" class="data row4 col1" >0.210000</td>
#                         <td id="T_b0dc6_row4_col2" class="data row4 col2" >0.340000</td>
#                         <td id="T_b0dc6_row4_col3" class="data row4 col3" >0.240000</td>
#                         <td id="T_b0dc6_row4_col4" class="data row4 col4" >0.000000</td>
#                         <td id="T_b0dc6_row4_col5" class="data row4 col5" >0.000000</td>
#                         <td id="T_b0dc6_row4_col6" class="data row4 col6" >0.340000</td>
#                         <td id="T_b0dc6_row4_col7" class="data row4 col7" >0.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_b0dc6_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b0dc6_row5_col0" class="data row5 col0" >0.280000</td>
#                         <td id="T_b0dc6_row5_col1" class="data row5 col1" >0.170000</td>
#                         <td id="T_b0dc6_row5_col2" class="data row5 col2" >0.420000</td>
#                         <td id="T_b0dc6_row5_col3" class="data row5 col3" >0.000000</td>
#                         <td id="T_b0dc6_row5_col4" class="data row5 col4" >0.000000</td>
#                         <td id="T_b0dc6_row5_col5" class="data row5 col5" >0.000000</td>
#                         <td id="T_b0dc6_row5_col6" class="data row5 col6" >0.420000</td>
#                         <td id="T_b0dc6_row5_col7" class="data row5 col7" >0.420000</td>
#             </tr>
#     </tbody></table>

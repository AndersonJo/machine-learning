# %% [markdown]
# # Autoencoders in Keras
#
# * [A Tutorial on Deep Learning PDF](http://ai.stanford.edu/~quocle/tutorial2.pdf)

# %%
# %pylab inline
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist

from keras.utils.visualize_util import plot as keras_plot
from IPython.display import SVG, Image
from keras.utils.visualize_util import model_to_dot
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using TensorFlow backend.

# %% [markdown]
# ### Data

# %%
(train_x, train_y), (test_x, test_y) = mnist.load_data()
train_x = train_x.astype('float32')/255.
train_y = train_y.astype('float32')
test_x = test_x.astype('float32')/255.
test_y = test_y.astype('float32')

print('Train x Shape:', train_x.shape)
print('Train y Shape:', train_y.shape)
print('Test x Shape:', test_x.shape)
print('Test y Shape:', test_y.shape)

# Reshape
train_x = train_x.reshape((len(train_x), np.prod(train_x.shape[1:]))) # (60000, 28*28=784))
test_x = test_x.reshape((len(test_x), np.prod(test_x.shape[1:]))) # (60000, 28*28=784))


print('\n[After Reshaping]')
print('Train x Shape:', train_x.shape)
print('Train y Shape:', train_y.shape)
print('Test x Shape:', test_x.shape)
print('Test y Shape:', test_y.shape)
# Out:
# Train x Shape: (60000, 28, 28)
# Train y Shape: (60000,)
# Test x Shape: (10000, 28, 28)
# Test y Shape: (10000,)
#
# [After Reshaping]
# Train x Shape: (60000, 784)
# Train y Shape: (60000,)
# Test x Shape: (10000, 784)
# Test y Shape: (10000,)

# %% [markdown]
# ### Autoencoder Model

# %%
encoding_dim = 32  

input_img = Input(shape=(784,), name='InputLayer')
encoded = Dense(output_dim=encoding_dim, activation='relu', name='EncodeLayer')(input_img)
decoded = Dense(784, activation='sigmoid', name='DecodeLayer')(encoded)

# Input -> Recontruction
autoencoder = Model(input=input_img, output=decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Visualization
SVG(model_to_dot(autoencoder, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Encoder Model

# %%
# Input Image -> Encoded 
encoder = Model(input=input_img, output=encoded, name='Input2')
SVG(model_to_dot(encoder, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Decoder Model

# %%
encoded_input = Input(shape=(encoding_dim,), name='Input3')
decoded_layer = autoencoder.layers[-1] # 마지막 layer를 꺼내옴
decoder = Model(input=encoded_input, output=decoded_layer(encoded_input))
SVG(model_to_dot(decoder, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Training

# %%
autoencoder.fit(train_x, train_x, 
                nb_epoch=50, 
                batch_size=256, 
                shuffle=True,
                validation_data=(test_x, test_x), 
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 1s - loss: 0.3733 - val_loss: 0.2732
# Epoch 2/50
# 0s - loss: 0.2670 - val_loss: 0.2577
# Epoch 3/50
# 0s - loss: 0.2478 - val_loss: 0.2352
# Epoch 4/50
# 0s - loss: 0.2269 - val_loss: 0.2165
# Epoch 5/50
# 0s - loss: 0.2116 - val_loss: 0.2042
# Epoch 6/50
# 0s - loss: 0.2009 - val_loss: 0.1947
# Epoch 7/50
# 0s - loss: 0.1923 - val_loss: 0.1872
# Epoch 8/50
# 0s - loss: 0.1854 - val_loss: 0.1809
# Epoch 9/50
# 0s - loss: 0.1797 - val_loss: 0.1757
# Epoch 10/50
# 0s - loss: 0.1748 - val_loss: 0.1712
# Epoch 11/50
# 0s - loss: 0.1704 - val_loss: 0.1668
# Epoch 12/50
# 0s - loss: 0.1661 - val_loss: 0.1627
# Epoch 13/50
# 0s - loss: 0.1621 - val_loss: 0.1588
# Epoch 14/50
# 0s - loss: 0.1582 - val_loss: 0.1550
# Epoch 15/50
# 0s - loss: 0.1547 - val_loss: 0.1516
# Epoch 16/50
# 0s - loss: 0.1514 - val_loss: 0.1484
# Epoch 17/50
# 0s - loss: 0.1484 - val_loss: 0.1455
# Epoch 18/50
# 0s - loss: 0.1456 - val_loss: 0.1428
# Epoch 19/50
# 0s - loss: 0.1431 - val_loss: 0.1404
# Epoch 20/50
# 0s - loss: 0.1407 - val_loss: 0.1381
# Epoch 21/50
# 0s - loss: 0.1385 - val_loss: 0.1359
# Epoch 22/50
# 0s - loss: 0.1365 - val_loss: 0.1340
# Epoch 23/50
# 0s - loss: 0.1345 - val_loss: 0.1320
# Epoch 24/50
# 0s - loss: 0.1327 - val_loss: 0.1302
# Epoch 25/50
# 0s - loss: 0.1309 - val_loss: 0.1284
# Epoch 26/50
# 0s - loss: 0.1292 - val_loss: 0.1268
# Epoch 27/50
# 0s - loss: 0.1276 - val_loss: 0.1252
# Epoch 28/50
# 0s - loss: 0.1261 - val_loss: 0.1236
# Epoch 29/50
# 0s - loss: 0.1246 - val_loss: 0.1221
# Epoch 30/50
# 0s - loss: 0.1231 - val_loss: 0.1207
# Epoch 31/50
# 0s - loss: 0.1217 - val_loss: 0.1194
# Epoch 32/50
# 0s - loss: 0.1204 - val_loss: 0.1180
# Epoch 33/50
# 0s - loss: 0.1192 - val_loss: 0.1168
# Epoch 34/50
# 0s - loss: 0.1180 - val_loss: 0.1156
# Epoch 35/50
# 0s - loss: 0.1168 - val_loss: 0.1145
# Epoch 36/50
# 0s - loss: 0.1158 - val_loss: 0.1134
# Epoch 37/50
# 0s - loss: 0.1148 - val_loss: 0.1124
# Epoch 38/50
# 0s - loss: 0.1138 - val_loss: 0.1115
# Epoch 39/50
# 0s - loss: 0.1129 - val_loss: 0.1107
# Epoch 40/50
# 0s - loss: 0.1121 - val_loss: 0.1099
# Epoch 41/50
# 0s - loss: 0.1113 - val_loss: 0.1091
# Epoch 42/50
# 0s - loss: 0.1106 - val_loss: 0.1084
# Epoch 43/50
# 0s - loss: 0.1099 - val_loss: 0.1078
# Epoch 44/50
# 0s - loss: 0.1092 - val_loss: 0.1071
# Epoch 45/50
# 0s - loss: 0.1086 - val_loss: 0.1065
# Epoch 46/50
# 0s - loss: 0.1081 - val_loss: 0.1060
# Epoch 47/50
# 0s - loss: 0.1075 - val_loss: 0.1055
# Epoch 48/50
# 0s - loss: 0.1070 - val_loss: 0.1050
# Epoch 49/50
# 0s - loss: 0.1065 - val_loss: 0.1046
# Epoch 50/50
# 0s - loss: 0.1061 - val_loss: 0.1041

# %% [markdown]
# ### Predict

# %%
encoded_images = encoder.predict(test_x)
decoded_images = decoder.predict(encoded_images)

# %%
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(test_x[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_images[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

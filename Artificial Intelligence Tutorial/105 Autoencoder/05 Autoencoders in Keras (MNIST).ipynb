# %% [markdown]
# # Autoencoders in Keras
#
# * [A Tutorial on Deep Learning PDF](http://ai.stanford.edu/~quocle/tutorial2.pdf)

# %%
# %pylab inline
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist

from keras.utils.visualize_util import plot as keras_plot
from IPython.display import SVG, Image
from keras.utils.visualize_util import model_to_dot
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using TensorFlow backend.

# %% [markdown]
# ### Data

# %%
(train_x, train_y), (test_x, test_y) = mnist.load_data()
train_x = train_x.astype('float32')/255.
train_y = train_y.astype('float32')
test_x = test_x.astype('float32')/255.
test_y = test_y.astype('float32')

print('Train x Shape:', train_x.shape)
print('Train y Shape:', train_y.shape)
print('Test x Shape:', test_x.shape)
print('Test y Shape:', test_y.shape)

# Reshape
train_x = train_x.reshape((len(train_x), np.prod(train_x.shape[1:]))) # (60000, 28*28=784))
test_x = test_x.reshape((len(test_x), np.prod(test_x.shape[1:]))) # (60000, 28*28=784))


print('\n[After Reshaping]')
print('Train x Shape:', train_x.shape)
print('Train y Shape:', train_y.shape)
print('Test x Shape:', test_x.shape)
print('Test y Shape:', test_y.shape)
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.pkl.gz
# Train x Shape: (60000, 28, 28)
# Train y Shape: (60000,)
# Test x Shape: (10000, 28, 28)
# Test y Shape: (10000,)
#
# [After Reshaping]
# Train x Shape: (60000, 784)
# Train y Shape: (60000,)
# Test x Shape: (10000, 784)
# Test y Shape: (10000,)

# %% [markdown]
# ### Autoencoder Model

# %%
encoding_dim = 32  

input_img = Input(shape=(784,), name='InputLayer')
encoded = Dense(output_dim=encoding_dim, activation='relu', name='EncodeLayer')(input_img)
decoded = Dense(784, activation='sigmoid', name='DecodeLayer')(encoded)

# Input -> Recontruction
autoencoder = Model(input=input_img, output=decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# Visualization
SVG(model_to_dot(autoencoder, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Encoder Model

# %%
# Input Image -> Encoded 
encoder = Model(input=input_img, output=encoded, name='Input2')
SVG(model_to_dot(encoder, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Decoder Model

# %%
encoded_input = Input(shape=(encoding_dim,), name='Input3')
decoded_layer = autoencoder.layers[-1] # 마지막 layer를 꺼내옴
decoder = Model(input=encoded_input, output=decoded_layer(encoded_input))
SVG(model_to_dot(encoder, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ### Training

# %%
autoencoder.fit(train_x, train_x, 
                nb_epoch=50, 
                batch_size=256, 
                shuffle=True,
                validation_data=(test_x, test_x), 
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 1s - loss: 0.3760 - val_loss: 0.2729
# Epoch 2/50
# 0s - loss: 0.2661 - val_loss: 0.2563
# Epoch 3/50
# 0s - loss: 0.2467 - val_loss: 0.2348
# Epoch 4/50
# 0s - loss: 0.2266 - val_loss: 0.2164
# Epoch 5/50
# 0s - loss: 0.2106 - val_loss: 0.2023
# Epoch 6/50
# 0s - loss: 0.1981 - val_loss: 0.1913
# Epoch 7/50
# 0s - loss: 0.1883 - val_loss: 0.1827
# Epoch 8/50
# 0s - loss: 0.1806 - val_loss: 0.1757
# Epoch 9/50
# 0s - loss: 0.1743 - val_loss: 0.1701
# Epoch 10/50
# 0s - loss: 0.1690 - val_loss: 0.1651
# Epoch 11/50
# 0s - loss: 0.1644 - val_loss: 0.1607
# Epoch 12/50
# 0s - loss: 0.1603 - val_loss: 0.1569
# Epoch 13/50
# 0s - loss: 0.1566 - val_loss: 0.1534
# Epoch 14/50
# 0s - loss: 0.1532 - val_loss: 0.1501
# Epoch 15/50
# 0s - loss: 0.1501 - val_loss: 0.1471
# Epoch 16/50
# 0s - loss: 0.1472 - val_loss: 0.1443
# Epoch 17/50
# 0s - loss: 0.1444 - val_loss: 0.1418
# Epoch 18/50
# 0s - loss: 0.1419 - val_loss: 0.1392
# Epoch 19/50
# 0s - loss: 0.1395 - val_loss: 0.1369
# Epoch 20/50
# 0s - loss: 0.1373 - val_loss: 0.1347
# Epoch 21/50
# 0s - loss: 0.1352 - val_loss: 0.1326
# Epoch 22/50
# 0s - loss: 0.1331 - val_loss: 0.1307
# Epoch 23/50
# 0s - loss: 0.1312 - val_loss: 0.1286
# Epoch 24/50
# 0s - loss: 0.1293 - val_loss: 0.1268
# Epoch 25/50
# 0s - loss: 0.1275 - val_loss: 0.1250
# Epoch 26/50
# 0s - loss: 0.1258 - val_loss: 0.1233
# Epoch 27/50
# 0s - loss: 0.1241 - val_loss: 0.1217
# Epoch 28/50
# 0s - loss: 0.1225 - val_loss: 0.1201
# Epoch 29/50
# 0s - loss: 0.1210 - val_loss: 0.1187
# Epoch 30/50
# 0s - loss: 0.1195 - val_loss: 0.1172
# Epoch 31/50
# 0s - loss: 0.1182 - val_loss: 0.1159
# Epoch 32/50
# 0s - loss: 0.1169 - val_loss: 0.1146
# Epoch 33/50
# 0s - loss: 0.1157 - val_loss: 0.1135
# Epoch 34/50
# 0s - loss: 0.1145 - val_loss: 0.1123
# Epoch 35/50
# 0s - loss: 0.1135 - val_loss: 0.1113
# Epoch 36/50
# 0s - loss: 0.1125 - val_loss: 0.1103
# Epoch 37/50
# 0s - loss: 0.1115 - val_loss: 0.1094
# Epoch 38/50
# 0s - loss: 0.1106 - val_loss: 0.1085
# Epoch 39/50
# 0s - loss: 0.1098 - val_loss: 0.1078
# Epoch 40/50
# 0s - loss: 0.1090 - val_loss: 0.1070
# Epoch 41/50
# 0s - loss: 0.1083 - val_loss: 0.1063
# Epoch 42/50
# 0s - loss: 0.1076 - val_loss: 0.1056
# Epoch 43/50
# 0s - loss: 0.1069 - val_loss: 0.1050
# Epoch 44/50
# 0s - loss: 0.1063 - val_loss: 0.1044
# Epoch 45/50
# 0s - loss: 0.1058 - val_loss: 0.1038
# Epoch 46/50
# 0s - loss: 0.1052 - val_loss: 0.1033
# Epoch 47/50
# 0s - loss: 0.1047 - val_loss: 0.1028
# Epoch 48/50
# 0s - loss: 0.1042 - val_loss: 0.1023
# Epoch 49/50
# 0s - loss: 0.1038 - val_loss: 0.1019
# Epoch 50/50
# 0s - loss: 0.1034 - val_loss: 0.1015

# %% [markdown]
# ### Predict

# %%
encoded_images = encoder.predict(test_x)
decoded_images = decoder.predict(encoded_images)

# %%
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(test_x[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_images[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# %pylab inline
import numpy as np
import pandas as pd
from IPython.display import display
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Data
#
# Data는 month(년-월)과, passenger(천단위의 승객 숫자)로 이루어져있습니다.

# %%
data = pd.read_csv('../../data/time-series/international-airline-passengers.csv', 
                   names=['month', 'passenger'],
                   skiprows=1)

data['month'] = pd.to_datetime(data['month'], format='%Y-%m') # Convert string -> datetime

display(data.head())
display(data.describe())
# Out:
#        month  passenger
# 0 1949-01-01        112
# 1 1949-02-01        118
# 2 1949-03-01        132
# 3 1949-04-01        129
# 4 1949-05-01        121
#         passenger
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
data.plot(x='month', y='passenger', color='#01878D')
ylabel('the number of passengers in thousands')
xlabel('')
legend(loc='upper left')
grid()

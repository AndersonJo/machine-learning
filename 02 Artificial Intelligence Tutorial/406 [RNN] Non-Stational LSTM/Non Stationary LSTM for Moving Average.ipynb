# %% [markdown]
# # Non Stationary LSTM
#
# 주가처럼 그래프 자체만으로는 random walk수준의 그래프 이지만, 외부변수를 줌으로서 LSTM이 어떻게 예측을 할 수 있는지 테스트

# %%
# %pylab inline
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation
from keras.layers.normalization import BatchNormalization
from keras.activations import relu
from keras.metrics import mean_squared_error
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor

from sklearn.metrics import make_scorer, r2_score
from sklearn.model_selection import GridSearchCV

from IPython.display import SVG, Image
from keras.utils.vis_utils import model_to_dot
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Data

# %%
BATCH_SIZE=5000
TIME_SERIES_LENGTH = 30

def g1(x):
    return 1/(np.e * (x+0.023))

def g2(x):
    return -1/(x+0.02)

def g3(x):
    return 1/(x + 1.7)

def g4(x):
    return 3

def g5(x):
    return -1

def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

def create_data(batch_size=1000, time_series_length=500, moving_avg_n=1):
    funcs = [np.sin, np.cos, g1, g2, g3, g4, g5]
    func_count = len(funcs)
    
    x_data = np.zeros((batch_size, time_series_length, func_count + 1))
    y_data = np.zeros((batch_size, time_series_length, 1))
    
    for batch_idx in range(batch_size):
        x = np.zeros((time_series_length, func_count+1), dtype=np.float16)
        y = np.zeros((time_series_length, 1))
        for t in range(time_series_length):
            selected_func_idx = np.random.randint(func_count)
            
            x[t, 0] = t/time_series_length
            x[t, selected_func_idx + 1] = 1
            y[t, 0] = funcs[selected_func_idx](t)
        
        y = np.cumsum(y, axis=0)
        y[moving_avg_n:] = y[moving_avg_n:] - y[:moving_avg_n]
        y = y[moving_avg_n-1:] / moving_avg_n
                
        x_data[batch_idx, :] = x
        y_data[batch_idx, :] = y
      
    print(x_data.shape)    
    return x_data, y_data
    
data_x, data_y = create_data(batch_size=BATCH_SIZE, 
                             time_series_length=TIME_SERIES_LENGTH)

# Scaling
y_shape = data_y.shape
scaler_y = StandardScaler()
data_y = scaler_y.fit_transform(data_y.reshape(-1, 1))
data_y = data_y.reshape(y_shape)

print('data x shape:', data_x.shape)
print('data y shape:', data_y.shape)
plot(data_y[0])
# Out:
# (5000, 30, 8)
# data x shape: (5000, 30, 8)
# data y shape: (5000, 30, 1)

# %%
def visualize(data_x, data_y):
    fig, sub_plots = subplots(2, 2)
    for columns in sub_plots:
        for sp in columns:
            sp.get_xaxis().set_visible(False)
            sp.get_yaxis().set_visible(False)
                        
            batch_idx = np.random.randint(data_x.shape[0])
            sample_x = data_x[batch_idx]
            sample_y = data_y[batch_idx]
                                    
            sample_x = sample_x[:, 0].reshape((-1, 1))
            
            tick_x = range(sample_x.shape[0])
            
            sp.plot(tick_x, sample_x, label='x')
            sp.plot(tick_x, sample_y, label='y')
            sp.legend()

visualize(data_x, data_y)

# %% [markdown]
# ## Model

# %%
def create_model(lstm_out1=5, lstm_out2=5, lstm_out3=5, dense1=10, optimizer='adam'):
    model = Sequential(name='lstm')
    model.add(LSTM(lstm_out1, batch_input_shape=(None, None, 8), return_sequences=True))
    if lstm_out2 is not None:
        model.add(LSTM(lstm_out2, return_sequences=True))
    
    if lstm_out3 is not None:
        model.add(LSTM(lstm_out3, return_sequences=True))
    
    model.add(Dense(dense1, name='fully_connected_layer01'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dense(1, name='fully_connected_layer02'))
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=[mean_squared_error])
    return model
model = create_model()
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## Hyperparameter Optimization

# %%
# Custom Scorer
def accuracy(y_true, y_pred):
    y_true = y_true.reshape((-1, 1))
    y_pred = y_pred.reshape((-1, 1))
    score = r2_score(y_true, y_pred, multioutput='variance_weighted')
    error = ((y_true - y_pred)**2).mean()
    print(f'error:{error}, score:{score}')
    return scoreepochs

# Grid Search 
params = dict(lstm_out1=[1, 4, 6, 10, 20, 50, 100], 
              lstm_out2=[None, 4, 6, 10, 20, 100], 
              lstm_out3=[None, 4, 6, 10, 20, 100], 
              optimizer=['adam'], 
              nb_epoch=[30, 200])

classifier = KerasRegressor(create_model, verbose=0)
scorer = make_scorer(accuracy, greater_is_better=False) # 케라스 모델에서 MSE를 사용하기 때문에 greater_is_better는 False
grid = GridSearchCV(classifier, param_grid=params, scoring=scorer, n_jobs=1)
grid_result = grid.fit(X=data_x, y=data_y)
# Out:
# error:0.9311342615786549, score:0.07817997538455923
# error:0.9163804572449392, score:0.07895236105238568
# error:0.31095936531420015, score:0.6801578204652571
# error:0.3107998050428667, score:0.6934531949317241
# error:0.34206862551535344, score:0.663860378094901
# error:0.3382513206735442, score:0.6587407854169831
# error:0.8693935414821076, score:0.13930309636464433
# error:0.8558105224767423, score:0.1398307822020276
# error:0.36614872148160454, score:0.6233919342027032
# error:0.36273071819238933, score:0.6422329069779764
# error:0.21431603757455653, score:0.7893986572724221
# error:0.20435610607659627, score:0.7938266608506478
# error:1.880101080065185, score:-0.8612942251387726
# error:1.8749547133368079, score:-0.8845039723397102
# error:0.7633453886800038, score:0.21484901216429575
# error:0.7635848848194091, score:0.24686404868390166
# error:0.7523866886643324, score:0.26065427171803945
# error:0.7433186157156981, score:0.2500714365905078
# error:1.8072063181948788, score:-0.7891286374740059
# error:1.8172515786435604, score:-0.8265069520530955
# error:0.7313034130017989, score:0.24780629366363582
# error:0.7432020737767796, score:0.2669679403274844
# error:1.8089175998485592, score:-0.7775640111819674
# error:1.7885999590624613, score:-0.8045050526852574
# error:1.1233889408021094, score:-0.11215155944021538
# error:1.1235587731356862, score:-0.12928112666952774
# error:0.515712372935439, score:0.4695558720154983
# error:0.5169003940467227, score:0.4901728966281008
# error:1.1285647172202402, score:-0.10900354211181407
# error:1.1256713690689253, score:-0.13568138188527734
# error:0.1497519989023233, score:0.8517459865773715
# error:0.148980939131407, score:0.8502602918358575
# error:6.601186621134725, score:-5.789755035311362
# error:6.59238403818024, score:-5.5021735274529044
# error:9.06928217513559, score:-7.912086212840649
# error:9.083183125247643, score:-8.163955171153198
# error:0.3004710627953287, score:0.7025345818200027
# error:0.2994688243097446, score:0.6990059626564221
# error:2.8826165250894964, score:-1.9649608758877564
# error:2.8828306492724716, score:-1.8433818514316418
# error:0.18109356263327425, score:0.822045294036287
# error:0.17860286865597802, score:0.8198089084812852
# error:1.2451939724826264, score:-0.23273816218389912
# error:1.23754766907843, score:-0.24385057502938823
# error:0.47523202388891655, score:0.5111925760725851
# error:2.600820675353924, score:-1.6751152921337469
# error:2.6075129090758034, score:-1.571831572871249
# error:0.1584831104029861, score:0.8442638440489985
# error:0.15717177181585226, score:0.8414305809724693
# error:0.2641556291195546, score:0.7384867482757471
# error:0.2633004688570159, score:0.7353585257550584
# error:0.9753511950534837, score:-0.003212917297128915
# error:0.9683907725251204, score:0.044860734921530754
# error:0.054147011946767194, score:0.9467915068338816
# error:0.05293803992898596, score:0.9465912094836556
# error:0.9173610849347721, score:0.09181537744931755
# error:0.9145202346273352, score:0.08082205789752817
# error:0.16112811739122446, score:0.8342691232384448
# error:0.1628326253713497, score:0.8393955843647258
# error:0.092315012617253, score:0.9092850640991187
# error:0.09113903382168786, score:0.9080505139258224
# error:0.2017720057119248, score:0.8002463415353966
# error:0.20569794132290992, score:0.7932544264841181
# error:2.414338771295021, score:-1.4833063765935384
# error:2.4210543523830075, score:-1.387924524332608
# error:0.30830897745272656, score:0.6970348772712693
# error:0.3069992993847491, score:0.6902707147544624
# error:0.4273774712696325, score:0.5768976319076426
# error:0.425828923106906, score:0.5720023041495443
# error:1.5291204429727172, score:-0.5728010467134546
# error:1.5850013866691082, score:-0.5633121489416253
# error:0.15135483296293126, score:0.8512685685539857
# error:0.15001893308751793, score:0.8486470261931702
# error:0.14891043676999122, score:0.8525791304724599
# error:0.15041771421909603, score:0.8488161991647926
# error:0.28543530455112914, score:0.7064109973611807
# error:0.2854229564269012, score:0.7184827854903558
# error:0.09054084523808682, score:0.9110284802078916
# error:0.08995517765528126, score:0.9092448975123306

# %%
_mean_scores = grid_result.cv_results_['mean_test_score']
_stds = grid_result.cv_results_['std_test_score']
_params = grid_result.cv_results_['params']

print('Best:', grid_result.best_params_)
for mean, std, param in zip(_mean_scores, _stds, _params):
    print(f'Mean Score:{mean:.7},\tSTD Score:{std:.5},\tParams: {param}')

# %% [markdown]
# ## Training

# %%
model = create_model(lstm_out1=20, lstm_out2=20, lstm_out3=None, dense1=1024)
model.fit(data_x, data_y, verbose=2, epochs=300)
# Out:
# Epoch 1/300
# 8s - loss: 0.4159 - mean_squared_error: 0.4159
# Epoch 2/300
# 8s - loss: 0.2461 - mean_squared_error: 0.2461
# Epoch 3/300
# 8s - loss: 0.1298 - mean_squared_error: 0.1298
# Epoch 4/300
# 8s - loss: 0.1007 - mean_squared_error: 0.1007
# Epoch 5/300
# 8s - loss: 0.0852 - mean_squared_error: 0.0852
# Epoch 6/300
# 7s - loss: 0.0817 - mean_squared_error: 0.0817
# Epoch 7/300
# 8s - loss: 0.0810 - mean_squared_error: 0.0810
# Epoch 8/300
# 8s - loss: 0.0792 - mean_squared_error: 0.0792
# Epoch 9/300
# 7s - loss: 0.0766 - mean_squared_error: 0.0766
# Epoch 10/300
# 8s - loss: 0.0805 - mean_squared_error: 0.0805
# Epoch 11/300
# 8s - loss: 0.0698 - mean_squared_error: 0.0698
# Epoch 12/300
# 7s - loss: 0.0716 - mean_squared_error: 0.0716
# Epoch 13/300
# 7s - loss: 0.0696 - mean_squared_error: 0.0696
# Epoch 14/300
# 8s - loss: 0.0690 - mean_squared_error: 0.0690
# Epoch 15/300
# 8s - loss: 0.0697 - mean_squared_error: 0.0697
# Epoch 16/300
# 8s - loss: 0.0650 - mean_squared_error: 0.0650
# Epoch 17/300
# 7s - loss: 0.0666 - mean_squared_error: 0.0666
# Epoch 18/300
# 8s - loss: 0.0651 - mean_squared_error: 0.0651
# Epoch 19/300
# 7s - loss: 0.0703 - mean_squared_error: 0.0703
# Epoch 20/300
# 7s - loss: 0.0641 - mean_squared_error: 0.0641
# Epoch 21/300
# 7s - loss: 0.0638 - mean_squared_error: 0.0638
# Epoch 22/300
# 7s - loss: 0.0614 - mean_squared_error: 0.0614
# Epoch 23/300
# 8s - loss: 0.0602 - mean_squared_error: 0.0602
# Epoch 24/300
# 8s - loss: 0.0595 - mean_squared_error: 0.0595
# Epoch 25/300
# 7s - loss: 0.0576 - mean_squared_error: 0.0576
# Epoch 26/300
# 8s - loss: 0.0581 - mean_squared_error: 0.0581
# Epoch 27/300
# 7s - loss: 0.0574 - mean_squared_error: 0.0574
# Epoch 28/300
# 7s - loss: 0.0531 - mean_squared_error: 0.0531
# Epoch 29/300
# 7s - loss: 0.0551 - mean_squared_error: 0.0551
# Epoch 30/300
# 7s - loss: 0.0516 - mean_squared_error: 0.0516
# Epoch 31/300
# 7s - loss: 0.0516 - mean_squared_error: 0.0516
# Epoch 32/300
# 7s - loss: 0.0506 - mean_squared_error: 0.0506
# Epoch 33/300
# 7s - loss: 0.0481 - mean_squared_error: 0.0481
# Epoch 34/300
# 8s - loss: 0.0477 - mean_squared_error: 0.0477
# Epoch 35/300
# 7s - loss: 0.0491 - mean_squared_error: 0.0491
# Epoch 36/300
# 8s - loss: 0.0506 - mean_squared_error: 0.0506
# Epoch 37/300
# 8s - loss: 0.0475 - mean_squared_error: 0.0475
# Epoch 38/300
# 8s - loss: 0.0490 - mean_squared_error: 0.0490
# Epoch 39/300
# 8s - loss: 0.0470 - mean_squared_error: 0.0470
# Epoch 40/300
# 7s - loss: 0.0464 - mean_squared_error: 0.0464
# Epoch 41/300
# 7s - loss: 0.0439 - mean_squared_error: 0.0439
# Epoch 42/300
# 8s - loss: 0.0462 - mean_squared_error: 0.0462
# Epoch 43/300
# 8s - loss: 0.0433 - mean_squared_error: 0.0433
# Epoch 44/300
# 7s - loss: 0.0442 - mean_squared_error: 0.0442
# Epoch 45/300
# 7s - loss: 0.0452 - mean_squared_error: 0.0452
# Epoch 46/300
# 7s - loss: 0.0445 - mean_squared_error: 0.0445
# Epoch 47/300
# 7s - loss: 0.0436 - mean_squared_error: 0.0436
# Epoch 48/300
# 8s - loss: 0.0455 - mean_squared_error: 0.0455
# Epoch 49/300
# 8s - loss: 0.0434 - mean_squared_error: 0.0434
# Epoch 50/300
# 8s - loss: 0.0422 - mean_squared_error: 0.0422
# Epoch 51/300
# 7s - loss: 0.0420 - mean_squared_error: 0.0420
# Epoch 52/300
# 7s - loss: 0.0430 - mean_squared_error: 0.0430
# Epoch 53/300
# 7s - loss: 0.0428 - mean_squared_error: 0.0428
# Epoch 54/300
# 7s - loss: 0.0417 - mean_squared_error: 0.0417
# Epoch 55/300
# 8s - loss: 0.0407 - mean_squared_error: 0.0407
# Epoch 56/300
# 7s - loss: 0.0406 - mean_squared_error: 0.0406
# Epoch 57/300
# 7s - loss: 0.0403 - mean_squared_error: 0.0403
# Epoch 58/300
# 7s - loss: 0.0395 - mean_squared_error: 0.0395
# Epoch 59/300
# 8s - loss: 0.0390 - mean_squared_error: 0.0390
# Epoch 60/300
# 8s - loss: 0.0392 - mean_squared_error: 0.0392
# Epoch 61/300
# 7s - loss: 0.0391 - mean_squared_error: 0.0391
# Epoch 62/300
# 7s - loss: 0.0398 - mean_squared_error: 0.0398
# Epoch 63/300
# 8s - loss: 0.0404 - mean_squared_error: 0.0404
# Epoch 64/300
# 8s - loss: 0.0393 - mean_squared_error: 0.0393
# Epoch 65/300
# 8s - loss: 0.0380 - mean_squared_error: 0.0380
# Epoch 66/300
# 8s - loss: 0.0383 - mean_squared_error: 0.0383
# Epoch 67/300
# 7s - loss: 0.0388 - mean_squared_error: 0.0388
# Epoch 68/300
# 7s - loss: 0.0377 - mean_squared_error: 0.0377
# Epoch 69/300
# 8s - loss: 0.0372 - mean_squared_error: 0.0372
# Epoch 70/300
# 7s - loss: 0.0371 - mean_squared_error: 0.0371
# Epoch 71/300
# 8s - loss: 0.0358 - mean_squared_error: 0.0358
# Epoch 72/300
# 6s - loss: 0.0352 - mean_squared_error: 0.0352
# Epoch 73/300
# 6s - loss: 0.0346 - mean_squared_error: 0.0346
# Epoch 74/300
# 6s - loss: 0.0338 - mean_squared_error: 0.0338
# Epoch 75/300
# 6s - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 76/300
# 6s - loss: 0.0324 - mean_squared_error: 0.0324
# Epoch 77/300
# 5s - loss: 0.0309 - mean_squared_error: 0.0309
# Epoch 78/300
# 5s - loss: 0.0281 - mean_squared_error: 0.0281
# Epoch 79/300
# 5s - loss: 0.0248 - mean_squared_error: 0.0248
# Epoch 80/300
# 5s - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 81/300
# 5s - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 82/300
# 5s - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 83/300
# 5s - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 84/300
# 5s - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 85/300
# 5s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 86/300
# 5s - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 87/300
# 5s - loss: 0.0095 - mean_squared_error: 0.0095
# Epoch 88/300
# 6s - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 89/300
# 6s - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 90/300
# 6s - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 91/300
# 6s - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 92/300
# 6s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 93/300
# 6s - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 94/300
# 6s - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 95/300
# 6s - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 96/300
# 6s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 97/300
# 5s - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 98/300
# 5s - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 99/300
# 5s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 100/300
# 5s - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 101/300
# 5s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 102/300
# 6s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 103/300
# 7s - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 104/300
# 7s - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 105/300
# 7s - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 106/300
# 7s - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 107/300
# 7s - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 108/300
# 7s - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 109/300
# 7s - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 110/300
# 7s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 111/300
# 7s - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 112/300
# 7s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 113/300
# 7s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 114/300
# 7s - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 115/300
# 7s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 116/300
# 7s - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 117/300
# 7s - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 118/300
# 7s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 119/300
# 7s - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 120/300
# 7s - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 121/300
# 7s - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 122/300
# 7s - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 123/300
# 7s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 124/300
# 7s - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 125/300
# 7s - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 126/300
# 7s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 127/300
# 7s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 128/300
# 7s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 129/300
# 7s - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 130/300
# 7s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 131/300
# 7s - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 132/300
# 7s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 133/300
# 7s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 134/300
# 7s - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 135/300
# 7s - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 136/300
# 7s - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 137/300
# 7s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 138/300
# 7s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 139/300
# 7s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 140/300
# 7s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 141/300
# 7s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 142/300
# 7s - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 143/300
# 7s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 144/300
# 7s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 145/300
# 7s - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 146/300
# 7s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 147/300
# 7s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 148/300
# 7s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 149/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 150/300
# 7s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 151/300
# 7s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 152/300
# 7s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 153/300
# 7s - loss: 0.0032 - mean_squared_error: 0.0032
# Epoch 154/300
# 7s - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 155/300
# 7s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 156/300
# 7s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 157/300
# 7s - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 158/300
# 7s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 159/300
# 7s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 160/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 161/300
# 7s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 162/300
# 7s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 163/300
# 7s - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 164/300
# 7s - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 165/300
# 8s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 166/300
# 7s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 167/300
# 7s - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 168/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 169/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 170/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 171/300
# 7s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 172/300
# 7s - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 173/300
# 7s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 174/300
# 7s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 175/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 176/300
# 7s - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 177/300
# 7s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 178/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 179/300
# 7s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 180/300
# 7s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 181/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 182/300
# 7s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 183/300
# 7s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 184/300
# 7s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 185/300
# 7s - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 186/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 187/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 188/300
# 7s - loss: 0.0026 - mean_squared_error: 0.0026
# Epoch 189/300
# 7s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 190/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 191/300
# 7s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 192/300
# 7s - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 193/300
# 7s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 194/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 195/300
# 7s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 196/300
# 7s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 197/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 198/300
# 7s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 199/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 200/300
# 7s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 201/300
# 7s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 202/300
# 7s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 203/300
# 7s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 204/300
# 7s - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 205/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 206/300
# 7s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 207/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 208/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 209/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 210/300
# 7s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 211/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 212/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 213/300
# 7s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 214/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 215/300
# 8s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 216/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 217/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 218/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 219/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 220/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 221/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 222/300
# 7s - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 223/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 224/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 225/300
# 7s - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 226/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 227/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 228/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 229/300
# 7s - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 230/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 231/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 232/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 233/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 234/300
# 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 235/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 236/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 237/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 238/300
# 7s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 239/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 240/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 241/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 242/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 243/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 244/300
# 7s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 245/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 246/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 247/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 248/300
# 7s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 249/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 250/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 251/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 252/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 253/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 254/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 255/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 256/300
# 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 257/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 258/300
# 8s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 259/300
# 8s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 260/300
# 8s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 261/300
# 8s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 262/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 263/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 264/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 265/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 266/300
# 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 267/300
# 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 268/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 269/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 270/300
# 8s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 271/300
# 8s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 272/300
# 7s - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 273/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 274/300
# 7s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 275/300
# 8s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 276/300
# 8s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 277/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 278/300
# 7s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 279/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 280/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 281/300
# 7s - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 282/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 283/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 284/300
# 7s - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 285/300
# 7s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 286/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 287/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 288/300
# 7s - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 289/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 290/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 291/300
# 7s - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 292/300
# 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 293/300
# 8s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 294/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 295/300
# 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 296/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 297/300
# 7s - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 298/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 299/300
# 7s - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 300/300
# 7s - loss: 0.0013 - mean_squared_error: 0.0013

# %%
def accuracy(y_true, y_pred):
    y_true = y_true.reshape((-1, 1))
    y_pred = y_pred.reshape((-1, 1))
    score = r2_score(y_true, y_pred, multioutput='variance_weighted')
    error = ((y_true - y_pred)**2).mean()
    print(f'error:{error}, score:{score}')
    return score


def visualize_prediction(data_x, data_y):
    pred_y = model.predict(data_x)
    
    print('score:', accuracy(data_y, pred_y))
    
    fig, sub_plots = subplots(2, 2)
    
    for col_plots in sub_plots:
        for sp in col_plots:
            sp.get_xaxis().set_visible(False)
            sp.get_yaxis().set_visible(False)
            
            idx = np.random.randint(data_x.shape[0])
            sp.plot(data_y[idx], color='#555555')
            sp.plot(pred_y[idx], color='red', linestyle='--')
            

visualize_prediction(data_x, data_y)
# Out:
# error:0.01373816696803562, score:0.9862618330319642
# score: 0.986261833032

# %% [markdown]
# # Test
#
# ### test1
#
# ```
# model = create_model(lstm_out1=20, lstm_out2=20, lstm_out3=None, dense1=1024)
# model.fit(data_x, data_y, verbose=2, epochs=300)
#
# error:0.01373816696803562, score:0.9862618330319642
# score: 0.986261833032
# ```

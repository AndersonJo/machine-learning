# %%
a<-iris[,-5]
head(a)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1 5.1          3.5         1.4          0.2
# 2 4.9          3.0         1.4          0.2
# 3 4.7          3.2         1.3          0.2
# 4 4.6          3.1         1.5          0.2
# 5 5.0          3.6         1.4          0.2
# 6 5.4          3.9         1.7          0.4

# %%
fit<-lm(Sepal.Length~., data=a)
summary(fit)
# Out:
# Call:
# lm(formula = Sepal.Length ~ ., data = a)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.82816 -0.21989  0.01875  0.19709  0.84570
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.85600    0.25078   7.401 9.85e-12 ***
# Sepal.Width   0.65084    0.06665   9.765  < 2e-16 ***
# Petal.Length  0.70913    0.05672  12.502  < 2e-16 ***
# Petal.Width  -0.55648    0.12755  -4.363 2.41e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3145 on 146 degrees of freedom
# Multiple R-squared:  0.8586,	Adjusted R-squared:  0.8557
# F-statistic: 295.5 on 3 and 146 DF,  p-value: < 2.2e-16

# %%
library(lmtest)
dwtest(fit)
# Out:
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
# 	Durbin-Watson test
#
# data:  fit
# DW = 2.0604, p-value = 0.6013
# alternative hypothesis: true autocorrelation is greater than 0

# %%
qqplot(scale(fit$res), scale(fit$fitted))
# Out:
# plot without title

# %%
shapiro.test(fit$res)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  fit$res
# W = 0.99559, p-value = 0.9349

# %%
plot(scale(fit$res),scale(fit$fitted))
# Out:
# plot without title

# %%
pairs(a)
# Out:
# plot without title

# %%
pairs(a[,-1])
# Out:
# plot without title

# %%
cor.test(a[,2],a[,3])
# Out:
# 	Pearson's product-moment correlation
#
# data:  a[, 2] and a[, 3]
# t = -5.7684, df = 148, p-value = 4.513e-08
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.5508771 -0.2879499
# sample estimates:
#        cor
# -0.4284401
